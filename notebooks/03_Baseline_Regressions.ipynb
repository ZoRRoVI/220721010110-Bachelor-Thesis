# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import numpy.linalg as la
from linearmodels.panel import PanelOLS, RandomEffects
from scipy import stats
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

# ==============================================================================
# 1. GLOBAL CONFIGURATION & DATA LOADING
# ==============================================================================
PROJECT_ROOT = Path.cwd().parent
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
master_file = PROCESSED_DIR / "master_panel_data.csv"

df = pd.read_csv(master_file)
df = df.set_index(['Country Name', 'Year'])

BRICS_NATIONS = ["Brazil", "Russia", "India", "China", "Egypt", "United Arab Emirates"]
OECD_EMERGING = ["Chile", "Colombia", "Costa Rica", "Turkey", "Hungary", "Poland"]

def categorize_economy(country):
    if country in BRICS_NATIONS: return 'BRICS (Developing)'
    elif country in OECD_EMERGING: return 'OECD (Emerging)'
    else: return 'OECD (Advanced)'

df['Economic_Bloc'] = [categorize_economy(c) for c, y in df.index]

TIME_SPLITS = {
    "PRE-CRISIS ERA (1995-2008)": (1995, 2008),
    "POST-CRISIS ERA (2009-2022)": (2009, 2022)
}

Y_VAR = 'GDP growth (annual %)'
X_VARS = [
    'General Government Debt (% of GDP)', 
    'Gross capital formation (% of GDP)',
    'Inflation (Annual %)',
    'Population growth (annual %)'
]

# ==============================================================================
# 2. EXCEL FORMATTER & ECONOMETRIC FUNCTIONS
# ==============================================================================
def print_excel_summary(res, model_title):
    """Parses linearmodels output into a strict Excel Solver format."""
    print(f"\nSUMMARY OUTPUT: {model_title}")
    
    # 1. Extract Regression Statistics safely
    nobs = res.nobs
    r2 = getattr(res, 'rsquared_inclusive', getattr(res, 'rsquared', np.nan))
    mult_r = np.sqrt(max(r2, 0)) if pd.notnull(r2) else "#N/A"
    
    df_resid = getattr(res, 'df_resid', np.nan)
    df_model = getattr(res, 'df_model', np.nan)
    
    adj_r2 = 1 - (1 - r2) * (nobs - 1) / df_resid if pd.notnull(df_resid) and df_resid > 0 else "#N/A"
    
    ssr = getattr(res, 'resid_ss', np.nan)
    sst = getattr(res, 'total_ss', np.nan)
    std_err = np.sqrt(ssr / df_resid) if pd.notnull(ssr) and df_resid > 0 else "#N/A"
    
    # Print Regression Statistics
    print("\nRegression Statistics")
    print(f"{'Multiple R':<20} {mult_r if isinstance(mult_r, str) else f'{mult_r:.8f}'}")
    print(f"{'R Square':<20} {r2 if isinstance(r2, str) else f'{r2:.8f}'}")
    print(f"{'Adjusted R Square':<20} {adj_r2 if isinstance(adj_r2, str) else f'{adj_r2:.8f}'}")
    print(f"{'Standard Error':<20} {std_err if isinstance(std_err, str) else f'{std_err:.8f}'}")
    print(f"{'Observations':<20} {nobs}")
    
    # Print ANOVA
    print("\nANOVA")
    print(f"{'':<12} {'df':<10} {'SS':<15} {'MS':<15} {'F':<15} {'Significance F'}")
    
    if pd.notnull(ssr) and pd.notnull(sst):
        ss_reg = sst - ssr
        ms_reg = ss_reg / df_model if df_model > 0 else np.nan
        ms_res = ssr / df_resid if df_resid > 0 else np.nan
        
        f_stat = getattr(res.f_statistic, 'stat', np.nan) if hasattr(res, 'f_statistic') else (ms_reg/ms_res if ms_res > 0 else np.nan)
        p_f = getattr(res.f_statistic, 'pval', np.nan) if hasattr(res, 'f_statistic') else np.nan
        
        print(f"{'Regression':<12} {df_model:<10} {ss_reg:<15.5E} {ms_reg:<15.5E} {f_stat:<15.6f} {p_f:.6f}")
        print(f"{'Residual':<12} {df_resid:<10} {ssr:<15.5E} {ms_res:<15.5E}")
        print(f"{'Total':<12} {nobs-1:<10} {sst:<15.5E}")
    else:
        print("ANOVA not applicable for this estimator.")
        
    # Print Coefficients
    print("\n" + "-"*120)
    print(f"{'':<40} {'Coefficients':<15} {'Standard Error':<15} {'t Stat':<10} {'P-value':<10} {'Lower 95%':<12} {'Upper 95%'}")
    
    params = res.params
    se = res.std_errors
    tstat = res.tstats
    pval = res.pvalues
    ci = res.conf_int()
    
    for var in params.index:
        c, s, t, p = params[var], se[var], tstat[var], pval[var]
        l, u = ci.loc[var, 'lower'], ci.loc[var, 'upper']
        print(f"{var[:38]:<40} {c:<15.6f} {s:<15.6f} {t:<10.6f} {p:<10.6f} {l:<12.6f} {u:<12.6f}")
    print("-" * 120 + "\n")


def hausman_test(fe_res, re_res):
    common_vars = set(fe_res.params.index).intersection(re_res.params.index)
    common_vars = [v for v in common_vars if v != 'const']
    b_fe, b_re = fe_res.params[common_vars], re_res.params[common_vars]
    v_fe, v_re = fe_res.cov.loc[common_vars, common_vars], re_res.cov.loc[common_vars, common_vars]
    df_haus = len(common_vars)
    b_diff, v_diff = b_fe - b_re, v_fe - v_re
    try: h_stat = float(b_diff.T @ la.inv(v_diff) @ b_diff)
    except la.LinAlgError: h_stat = float(b_diff.T @ la.pinv(v_diff) @ b_diff)
    return h_stat, stats.chi2.sf(h_stat, df_haus)

def execute_panel_models(data, dependent, independents, bloc_name):
    reg_data = data[[dependent] + independents].dropna()
    if len(reg_data) < 30: return
    
    n_entities = reg_data.index.get_level_values(0).nunique()
    n_vars = len(independents) + 1 
    
    Y = reg_data[dependent]
    X = sm.add_constant(reg_data[independents])
    
    fe_model = PanelOLS(Y, X, entity_effects=True, time_effects=True)
    fe_res = fe_model.fit(cov_type='robust')
    
    try:
        if n_entities <= n_vars + 1: raise ValueError("Small N")
        re_model = RandomEffects(Y, X)
        re_res = re_model.fit(cov_type='robust')
        h_stat, h_pval = hausman_test(fe_res, re_res)
        print(f"\n[HAUSMAN TEST] Chi2 = {h_stat:.2f} | p-value = {h_pval:.4f} -> {'Fixed Effects' if h_pval < 0.05 else 'Random Effects'} Preferred")
    except Exception:
        pass # Small N skipped silently for clean output
        
    # Execute our custom Excel Formatter instead of standard linearmodels print
    print_excel_summary(fe_res, model_title=bloc_name)

# ==============================================================================
# 3. PIPELINE EXECUTION
# ==============================================================================
if __name__ == "__main__":
    for time_label, (start_yr, end_yr) in TIME_SPLITS.items():
        print("\n" + "#"*120)
        print(f"### {time_label} ###")
        print("#"*120)
        
        df_time = df.loc[(slice(None), slice(start_yr, end_yr)), :]
        execute_panel_models(df_time, Y_VAR, X_VARS, "GLOBAL PANEL (ALL ENTITIES)")
        
        for bloc in ['OECD (Advanced)', 'OECD (Emerging)', 'BRICS (Developing)']:
            df_bloc = df_time[df_time['Economic_Bloc'] == bloc]
            execute_panel_models(df_bloc, Y_VAR, X_VARS, bloc)
# Out:
# ########################################################################################################################
# ### PRE-CRISIS ERA (1995-2008) ###
# ########################################################################################################################
#
# [HAUSMAN TEST] Chi2 = 19.68 | p-value = 0.0006 -> Fixed Effects Preferred
#
# SUMMARY OUTPUT: GLOBAL PANEL (ALL ENTITIES)
#
# Regression Statistics
# Multiple R           0.76749542
# R Square             0.58904923
# Adjusted R Square    0.54099450
# Standard Error       1.92125336
# Observations         555
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   59         3.42682E+02     5.80817E+00     23.209305       0.000000
# Residual     496        1.83084E+03     3.69121E+00
# Total        554        2.17352E+03
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    -1.922134       1.630053        -1.179185  0.238890   -5.124795    1.280526
# General Government Debt (% of GDP)       -0.001109       0.016254        -0.068233  0.945628   -0.033044    0.030826
# Gross capital formation (% of GDP)       0.273870        0.049426        5.540984   0.000000   0.176759     0.370981
# Inflation (Annual %)                     -0.055282       0.035541        -1.555466  0.120473   -0.125111    0.014547
# Population growth (annual %)             -1.019104       0.442502        -2.303050  0.021689   -1.888514    -0.149695
# ------------------------------------------------------------------------------------------------------------------------
#
#
# [HAUSMAN TEST] Chi2 = 59.01 | p-value = 0.0000 -> Fixed Effects Preferred
#
# SUMMARY OUTPUT: OECD (Advanced)
#
# Regression Statistics
# Multiple R           0.75490320
# R Square             0.56987884
# Adjusted R Square    0.51681928
# Standard Error       1.82083510
# Observations         429
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   48         2.71227E+02     5.65057E+00     20.451832       0.000000
# Residual     381        1.26318E+03     3.31544E+00
# Total        428        1.53441E+03
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    -2.607930       1.801884        -1.447335  0.148625   -6.150812    0.934953
# General Government Debt (% of GDP)       0.010612        0.009058        1.171645   0.242072   -0.007197    0.028422
# Gross capital formation (% of GDP)       0.266860        0.062468        4.271933   0.000025   0.144034     0.389686
# Inflation (Annual %)                     -0.164187       0.044823        -3.663057  0.000284   -0.252318    -0.076057
# Population growth (annual %)             -0.947192       0.480736        -1.970295  0.049528   -1.892420    -0.001964
# ------------------------------------------------------------------------------------------------------------------------
#
#
# SUMMARY OUTPUT: OECD (Emerging)
#
# Regression Statistics
# Multiple R           0.82506333
# R Square             0.68072950
# Adjusted R Square    0.52109424
# Standard Error       1.91806675
# Observations         64
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   22         9.65129E+01     4.38695E+00     6.558399        0.000340
# Residual     42         1.54517E+02     3.67898E+00
# Total        63         2.51030E+02
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    -9.390899       3.612966        -2.599222  0.012837   -16.682159   -2.099638
# General Government Debt (% of GDP)       -0.011829       0.052611        -0.224833  0.823200   -0.118003    0.094346
# Gross capital formation (% of GDP)       0.562572        0.106279        5.293336   0.000004   0.348092     0.777052
# Inflation (Annual %)                     -0.001358       0.059605        -0.022787  0.981928   -0.121647    0.118930
# Population growth (annual %)             1.148397        1.384970        0.829186   0.411687   -1.646585    3.943379
# ------------------------------------------------------------------------------------------------------------------------
#
#
# SUMMARY OUTPUT: BRICS (Developing)
#
# Regression Statistics
# Multiple R           0.90926593
# R Square             0.82676453
# Adjusted R Square    0.72904195
# Standard Error       1.61605975
# Observations         62
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   23         8.45056E+01     3.67416E+00     8.089296        0.000075
# Residual     39         1.01854E+02     2.61165E+00
# Total        61         1.86360E+02
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    14.783348       3.648128        4.052311   0.000234   7.404312     22.162384
# General Government Debt (% of GDP)       -0.088880       0.016663        -5.333957  0.000004   -0.122585    -0.055176
# Gross capital formation (% of GDP)       0.096575        0.084160        1.147512   0.258161   -0.073655    0.266806
# Inflation (Annual %)                     0.074268        0.026957        2.755063   0.008872   0.019742     0.128793
# Population growth (annual %)             -4.912313       2.076206        -2.366004  0.023046   -9.111837    -0.712789
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ########################################################################################################################
# ### POST-CRISIS ERA (2009-2022) ###
# ########################################################################################################################
#
# [HAUSMAN TEST] Chi2 = -51.67 | p-value = 1.0000 -> Random Effects Preferred
#
# SUMMARY OUTPUT: GLOBAL PANEL (ALL ENTITIES)
#
# Regression Statistics
# Multiple R           0.81788028
# R Square             0.66892815
# Adjusted R Square    0.63288897
# Standard Error       2.36935677
# Observations         602
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   60         4.02576E+02     6.70960E+00     17.927801       0.000000
# Residual     542        3.04271E+03     5.61385E+00
# Total        601        3.44528E+03
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    -3.677493       3.114094        -1.180919  0.238153   -9.794666    2.439680
# General Government Debt (% of GDP)       -0.007685       0.015962        -0.481445  0.630395   -0.039039    0.023669
# Gross capital formation (% of GDP)       0.267887        0.099584        2.690060   0.007364   0.072269     0.463505
# Inflation (Annual %)                     -0.106481       0.041060        -2.593324  0.009762   -0.187137    -0.025825
# Population growth (annual %)             0.637618        0.325969        1.956068   0.050970   -0.002700    1.277935
# ------------------------------------------------------------------------------------------------------------------------
#
#
# [HAUSMAN TEST] Chi2 = 126.93 | p-value = 0.0000 -> Fixed Effects Preferred
#
# SUMMARY OUTPUT: OECD (Advanced)
#
# Regression Statistics
# Multiple R           0.81089795
# R Square             0.65755548
# Adjusted R Square    0.61585887
# Standard Error       2.36894491
# Observations         434
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   48         1.82997E+02     3.81243E+00     8.152163        0.000003
# Residual     386        2.16619E+03     5.61190E+00
# Total        433        2.34919E+03
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    -3.004307       3.638544        -0.825689  0.409490   -10.158153   4.149540
# General Government Debt (% of GDP)       -0.000730       0.018718        -0.039019  0.968895   -0.037531    0.036071
# Gross capital formation (% of GDP)       0.209522        0.117435        1.784149   0.075185   -0.021371    0.440414
# Inflation (Annual %)                     -0.210009       0.100733        -2.084821  0.037742   -0.408063    -0.011956
# Population growth (annual %)             0.709872        0.473314        1.499792   0.134486   -0.220723    1.640467
# ------------------------------------------------------------------------------------------------------------------------
#
#
# SUMMARY OUTPUT: OECD (Emerging)
#
# Regression Statistics
# Multiple R           0.89989853
# R Square             0.80981736
# Adjusted R Square    0.74122690
# Standard Error       1.87036960
# Observations         84
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   23         9.20659E+01     4.00286E+00     6.579363        0.000181
# Residual     61         2.13395E+02     3.49828E+00
# Total        83         3.05461E+02
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    -1.608382       4.851425        -0.331528  0.741382   -11.309405   8.092641
# General Government Debt (% of GDP)       -0.054355       0.038105        -1.426444  0.158838   -0.130552    0.021841
# Gross capital formation (% of GDP)       0.364172        0.153816        2.367575   0.021092   0.056597     0.671747
# Inflation (Annual %)                     -0.123370       0.042711        -2.888456  0.005351   -0.208777    -0.037963
# Population growth (annual %)             -0.631590       1.069236        -0.590693  0.556908   -2.769660    1.506480
# ------------------------------------------------------------------------------------------------------------------------
#
#
# SUMMARY OUTPUT: BRICS (Developing)
#
# Regression Statistics
# Multiple R           0.82643241
# R Square             0.68299053
# Adjusted R Square    0.56865924
# Standard Error       2.61637184
# Observations         84
#
# ANOVA
#              df         SS              MS              F               Significance F
# Regression   23         9.55585E+01     4.15472E+00     3.489881        0.012448
# Residual     61         4.17569E+02     6.84540E+00
# Total        83         5.13128E+02
#
# ------------------------------------------------------------------------------------------------------------------------
#                                          Coefficients    Standard Error  t Stat     P-value    Lower 95%    Upper 95%
# const                                    3.928763        9.177170        0.428102   0.670085   -14.422123   22.279649
# General Government Debt (% of GDP)       -0.112131       0.064896        -1.727861  0.089073   -0.241898    0.017636
# Gross capital formation (% of GDP)       0.182706        0.248363        0.735643   0.464767   -0.313926    0.679338
# Inflation (Annual %)                     -0.078523       0.136076        -0.577050  0.566030   -0.350624    0.193579
# Population growth (annual %)             0.961342        0.666799        1.441727   0.154494   -0.372005    2.294689
# ------------------------------------------------------------------------------------------------------------------------
